# %%
## IMyKernel
##%noruncode
##%overwritefile
## %file:../src/IMyKernel.py
## %file:../../jupyter-MyPython-kernel/jupyter_MyPython_kernel/IMyKernel.py
##%fnlist:Python C Dart Kotlin Groovy Java Batch PS R Swift Lua Perl PHP Tcl Vimscript
##%fnlist:Gjs Vala Nodejs Bash VBScript WLS Go Html TypeScript Make Ruby Rust
##%fileforlist:../../jupyter-My$fnlist-kernel/jupyter_My$fnlist_kernel/IMyKernel.py
##
##   MyPython Jupyter IMyKernel
## 
from typing import Dict, Tuple, Sequence,List, Set
from abc import ABCMeta, abstractmethod
class IMyKernel():

    @abstractmethod
    def get_runfiletype(self)->str:
        pass
    @abstractmethod
    def get_kernelinfo(self)->str:
        pass
    @abstractmethod
    def get_main_head(self)->str:
        pass
    @abstractmethod
    def get_main_foot(self)->str:
        pass
    
    @abstractmethod
    def get_mymagics(self)->object:
        pass
    @abstractmethod
    def set_mymagics(self,object):
        pass
    
    @abstractmethod
    def get_execution_count(self):
        pass
    @abstractmethod
    def rawinput(self):
        pass
    @abstractmethod
    def sendresponse(self,contents,name='stdout',mimetype=None):
        pass

    @abstractmethod
    def do_execute(self, code, silent, store_history=True,
                   user_expressions=None, allow_stdin=True)->Dict:
        pass
    @abstractmethod
    def do_shutdown(self, restart):
        pass

    @abstractmethod
    def do_runcode(self,return_code,file_name,
                    magics,code, 
                    silent, store_history=True,
                    user_expressions=None, 
                    allow_stdin=True)->Dict:
        pass
    @abstractmethod
    def do_compile_code(self,return_code,file_name,
                    magics,code, silent, store_history=True,
                    user_expressions=None, 
                    allow_stdin=True)->Tuple[bool,Dict,Dict, str,str,str]:
        pass
    @abstractmethod
    def do_create_codefile(self,magics,code, 
                    silent, store_history=True,
                    user_expressions=None, 
                    allow_stdin=True)->Tuple[bool,Dict,Dict, str,str,str]:
        pass
    @abstractmethod
    def do_preexecute(self,code,magics,
                silent, store_history=True,
                user_expressions=None, 
                allow_stdin=False)->Tuple[bool,Dict,Dict,str]:
        pass
# Out:
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyC-kernel/jupyter_MyC_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyDart-kernel/jupyter_MyDart_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyKotlin-kernel/jupyter_MyKotlin_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyGroovy-kernel/jupyter_MyGroovy_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyJava-kernel/jupyter_MyJava_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyBatch-kernel/jupyter_MyBatch_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyPS-kernel/jupyter_MyPS_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyR-kernel/jupyter_MyR_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MySwift-kernel/jupyter_MySwift_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyLua-kernel/jupyter_MyLua_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyPerl-kernel/jupyter_MyPerl_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyPHP-kernel/jupyter_MyPHP_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyTcl-kernel/jupyter_MyTcl_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyVimscript-kernel/jupyter_MyVimscript_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyGjs-kernel/jupyter_MyGjs_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyVala-kernel/jupyter_MyVala_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyNodejs-kernel/jupyter_MyNodejs_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyBash-kernel/jupyter_MyBash_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyVBScript-kernel/jupyter_MyVBScript_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyWLS-kernel/jupyter_MyWLS_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyGo-kernel/jupyter_MyGo_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyHtml-kernel/jupyter_MyHtml_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyTypeScript-kernel/jupyter_MyTypeScript_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyMake-kernel/jupyter_MyMake_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyRuby-kernel/jupyter_MyRuby_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:copy to :/mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyRust-kernel/jupyter_MyRust_kernel/IMyKernel.py
# [MyPythonKernel144112] Info:file /mnt/h/Jupyter/Myjupyter-kernel/base/../../jupyter-MyPython-kernel/jupyter_MyPython_kernel/IMyKernel.py created successfully
