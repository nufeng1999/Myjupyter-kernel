# %%
##%overwritefile
##%file:src/compile_out_file.py
##%noruncode
    def getout_filename(self,cflags,defoutfile):
        outfile=''
        binary_filename=defoutfile
        index=0
        for s in cflags:
            if s.startswith('-o'):
                if(len(s)>2):
                    outfile=s[2:]
                    del cflags[index]
                else:
                    outfile=cflags[cflags.index('-o')+1]
                    if outfile.startswith('-'):
                        outfile=binary_filename
                    del cflags[cflags.index('-o')+1]
                    del cflags[cflags.index('-o')]
            binary_filename=outfile
            index+=1
        return binary_filename
# Out:
# [MyPythonKernel224345] Info:src/compile_out_file.py
# [MyPythonKernel224345] Info:file h:\Jupyter\Myjupyter-kernel\kernel\Make\src/compile_out_file.py created successfully

# %%
## new kernel.py
##%overwritefile
##%file:../../../jupyter-MyMake-kernel/jupyter_MyMake_kernel/kernel.py
###%file:make_kernel.py
##%noruncode
#
#   MyMake Jupyter Kernel
#   generated by MyPython
#
##%include:../../src/head.py
from .MyKernel import MyKernel

class MakeKernel(MyKernel):
    kernel_info={
        'info':'[MyMake Kernel]',
        'extension':'.makefile',
        'execsuffix':'',
        'needmain':'',
        'compiler':{
            'cmd':'',
            'clargs':[],
            'crargs':[],
        },
        'interpreter':{
            'cmd':'make',
            'clargs':['-f'],
            'crargs':[],
        },
    }
    implementation = 'jupyter_MyMake_kernel'
    implementation_version = '1.0'
    language = 'Make'
    language_version = ''
    language_info = {'name': 'text/make',
                     'mimetype': 'text/make',
                     'file_extension': kernel_info['extension']}
    runfiletype='script'
    banner = "Make kernel.\n" \
             "Uses Make, compiles in make, and creates source code files and executables in temporary folder.\n"

    main_head = "\n" \
            "\n" \
            "int main(List<String> arguments){\n"

    main_foot = "\nreturn 0;\n}"
    
##//%include:../../src/comm_attribute.py

    def __init__(self, *args, **kwargs):
        super(MakeKernel, self).__init__(*args, **kwargs)
        self.runfiletype='script'
        self.kernelinfo="[MyMakeKernel{0}]".format(time.strftime("%H%M%S", time.localtime()))
#################
##%include:src/compile_out_file.py
##%include:src/compile_with_sc.py
##%include:src/c_exec_sc_.py

##%include:src/do_make_runcode.py
##%include:src/do_make_compilecode.py
##%include:src/do_make_create_codefile.py
##%include:src/do_make_preexecute.py
# Out:
# [MyPythonKernel224345] Info:../../../jupyter-MyMake-kernel/jupyter_MyMake_kernel/kernel.py
# [MyPythonKernel224345] Info:file h:\Jupyter\Myjupyter-kernel\kernel\Make\../../../jupyter-MyMake-kernel/jupyter_MyMake_kernel/kernel.py created successfully
