# %%
## new kernel.py
##%overwritefile
##%file:../../../jupyter-MyCMake-kernel/jupyter_MyCMake_kernel/kernel.py
###%file:CMake_kernel.py
##%noruncode
#
#   MyCMake Jupyter Kernel
#   generated by MyPython
#
##%include:../../src/head.py
from .MyKernel import MyKernel

class CMakeKernel(MyKernel):
    kernel_info={
        'info':'[MyCMake Kernel]',
        'extension':'',
        'execsuffix':'',
        'needmain':'',
        'compiler':{
            'cmd':'',
            'outfileflag':'',
            'clargs':[],
            'crargs':[],
        },
        'interpreter':{
            'cmd':'cmake',
            'clargs':['-P'],
            'crargs':'',
        },
    }
    implementation = 'jupyter_MyCMake_kernel'
    implementation_version = '1.0'
    language = 'CMake'
    language_version = ''
    language_info = {'name': 'text/cMake',
                     'mimetype': 'text/cMake',
                     'file_extension': kernel_info['extension']}
    runfiletype='script'
    banner = "CMake kernel.\n" \
             "Uses CMake, compiles in cMake, and creates source code files and executables in temporary folder.\n"

    main_head = "\n\nint main(List<String> arguments){\n"
    main_foot = "\nreturn 0;\n}"
    
## //%include:../../src/comm_attribute.py
## __init__
    def __init__(self, *args, **kwargs):
        super(CMakeKernel, self).__init__(*args, **kwargs)
        self.runfiletype='script'
        self.kernelinfo="[MyCMakeKernel{0}]".format(time.strftime("%H%M%S", time.localtime()))
## #############################################
##%include:src/compile_out_file.py
##%include:src/compile_with_sc.py
##%include:src/c_exec_sc_.py

##%include:src/do_cMake_runcode.py
##%include:src/do_cMake_compilecode.py
##%include:src/do_cMake_create_codefile.py
##%include:src/do_cMake_preexecute.py
# Out:
# [MyPythonKernel174440] Info:file h:\Jupyter\Myjupyter-kernel\kernel\CMake\../../../jupyter-MyCMake-kernel/jupyter_MyCMake_kernel/kernel.py created successfully
