# %%
## new kernel.py
##%overwritefile
##%file:../../../jupyter-MyM4-kernel/jupyter_MyM4_kernel/kernel.py
###%file:m4_kernel.py
##%noruncode
#
#   MyM4 Jupyter Kernel
#   generated by MyPython
#
##%include:../../src/head.py
from .MyKernel import MyKernel

class M4Kernel(MyKernel):
    kernel_info={
        'info':'[MyM4 Kernel]',
        'extension':'.m4',
        'execsuffix':'',
        'needmain':'',
        'compiler':{
            'cmd':'',
            'outfileflag':'',
            'clargs':[],
            'crargs':[],
        },
        'interpreter':{
            'cmd':'m4',
            'clargs':'',
            'crargs':'',
        },
    }
    implementation = 'jupyter_MyM4_kernel'
    implementation_version = '1.0'
    language = 'M4'
    language_version = ''
    language_info = {'name': 'text/m4',
                     'mimetype': 'text/m4',
                     'file_extension': kernel_info['extension']}
    runfiletype='script'
    banner = "M4 kernel.\n" \
             "Uses M4, compiles in m4, and creates source code files and executables in temporary folder.\n"

    main_head = "\n\nint main(List<String> arguments){\n"
    main_foot = "\nreturn 0;\n}"
    
## //%include:../../src/comm_attribute.py
## __init__
    def __init__(self, *args, **kwargs):
        super(M4Kernel, self).__init__(*args, **kwargs)
        self.runfiletype='script'
        self.kernelinfo="[MyM4Kernel{0}]".format(time.strftime("%H%M%S", time.localtime()))
## #############################################
##%include:src/compile_out_file.py
##%include:src/compile_with_sc.py
##%include:src/c_exec_sc_.py

##%include:src/do_m4_runcode.py
##%include:src/do_m4_compilecode.py
##%include:src/do_m4_create_codefile.py
##%include:src/do_m4_preexecute.py
# Out:
# [MyPythonKernel214629] Info:../../../jupyter-MyM4-kernel/jupyter_MyM4_kernel/kernel.py
# [MyPythonKernel214629] Info:file H:/Jupyter/Myjupyter-kernel/kernel/M4/../../../jupyter-MyM4-kernel/jupyter_MyM4_kernel/kernel.py created successfully
