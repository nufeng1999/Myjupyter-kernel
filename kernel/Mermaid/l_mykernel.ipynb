# %%
## new kernel.py
##%overwritefile
##%file:../../../jupyter-MyMermaid-kernel/jupyter_MyMermaid_kernel/kernel.py
###%file:mermaid_kernel.py
##%noruncode
#
#   MyMermaid Jupyter Kernel
#   generated by MyPython
#
##%include:../../src/head.py
from .MyKernel import MyKernel

class MermaidKernel(MyKernel):
    kernel_info={
        'info':'[MyMermaid Kernel]',
        'extension':'.mmd',
        'execsuffix':'',
        'needmain':'',
        'compiler':{
            'cmd':'',
            'outfileflag':'',
            'clargs':[],
            'crargs':[],
        },
        'interpreter':{
            'cmd':'mmdc',
            'clargs':['-i'],
            'crargs':[''],
        },
    }
    implementation = 'jupyter_MyMermaid_kernel'
    implementation_version = '1.0'
    language = 'Mermaid'
    language_version = ''
    language_info = {'name': 'text/mermaid',
                     'mimetype': 'text/mermaid',
                     'file_extension': kernel_info['extension']}
    runfiletype='script'
    banner = "Mermaid kernel.\n" \
             "Uses Mermaid, compiles in mermaid, and creates source code files and executables in temporary folder.\n"

    main_head = "\n\nint main(List<String> arguments){\n"
    main_foot = "\nreturn 0;\n}"
    
## //%include:../../src/comm_attribute.py
## __init__
    def __init__(self, *args, **kwargs):
        super(MermaidKernel, self).__init__(*args, **kwargs)
        self.runfiletype='script'
        self.kernelinfo="[MyMermaidKernel{0}]".format(time.strftime("%H%M%S", time.localtime()))
## #############################################
##%include:src/compile_out_file.py
##%include:src/compile_with_sc.py
##%include:src/c_exec_sc_.py

##%include:src/do_mermaid_runcode.py
##%include:src/do_mermaid_compilecode.py
##%include:src/do_mermaid_create_codefile.py
##%include:src/do_mermaid_preexecute.py
# Out:
# [MyPythonKernel160012] Info:file h:\Jupyter\Myjupyter-kernel\kernel\Mermaid\../../../jupyter-MyMermaid-kernel/jupyter_MyMermaid_kernel/kernel.py created successfully
