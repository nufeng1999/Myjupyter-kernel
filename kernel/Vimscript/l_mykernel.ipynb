# %%
## new kernel.py
##%overwritefile
##%file:../../../jupyter-MyVimscript-kernel/jupyter_MyVimscript_kernel/kernel.py
###%file:vimscript_kernel.py
##%noruncode
#
#   MyVimscript Jupyter Kernel
#   generated by MyPython
#
##%include:../../src/head.py
from .MyKernel import MyKernel

class VimscriptKernel(MyKernel):
    kernel_info={
        'info':'[MyVimscript Kernel]',
        'extension':'.vim',
        'execsuffix':'',
        'needmain':'',
        'compiler':{
            'cmd':'',
            'outfileflag':'',
            'clargs':[],
            'crargs':[],
        },
        'interpreter':{
            'cmd':'vim',
            'clargs':['-N','-n','-c','q','-u'],
            'crargs':[],
        },
    }
    implementation = 'jupyter_MyVimscript_kernel'
    implementation_version = '1.0'
    language = 'VimL'
    language_version = ''
    language_info = {'name': 'text/viml',
                     'mimetype': 'text/viml',
                     'file_extension': kernel_info['extension']}
    runfiletype='script'
    banner = "Vim kernel.\n" \
             "Uses Vim, compiles in vimscript, and creates source code files and executables in temporary folder.\n"

    main_head = "\n\nint main(List<String> arguments){\n"
    main_foot = "\nreturn 0;\n}"
    
## //%include:../../src/comm_attribute.py
## __init__
    def __init__(self, *args, **kwargs):
        super(VimscriptKernel, self).__init__(*args, **kwargs)
        self.runfiletype='script'
        self.kernelinfo="[MyVimscriptKernel{0}]".format(time.strftime("%H%M%S", time.localtime()))
        
## #############################################
##%include:src/compile_out_file.py
##%include:src/compile_with_sc.py
##%include:src/c_exec_sc_.py

##%include:src/do_vimscript_runcode.py
##%include:src/do_vimscript_compilecode.py
##%include:src/do_vimscript_create_codefile.py
##%include:src/do_vimscript_preexecute.py
# Out:
# [MyPythonKernel224746] Info:../../../jupyter-MyVimscript-kernel/jupyter_MyVimscript_kernel/kernel.py
# [MyPythonKernel224746] Info:file h:\Jupyter\Myjupyter-kernel\kernel\Vimscript\../../../jupyter-MyVimscript-kernel/jupyter_MyVimscript_kernel/kernel.py created successfully
