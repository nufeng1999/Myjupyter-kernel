# %%
## new kernel.py
##%overwritefile
##%file:../../../jupyter-MyGradle-kernel/jupyter_MyGradle_kernel/kernel.py
###%file:gradle_kernel.py
##%noruncode
#
#   MyGradle Jupyter Kernel
#   generated by MyPython
#
##%include:../../src/head.py
from .MyKernel import MyKernel

class GradleKernel(MyKernel):
    kernel_info={
        'info':'[MyGradle Kernel]',
        'extension':'.gradle',
        'execsuffix':'',
        'needmain':'',
        'compiler':{
            'cmd':'',
            'outfileflag':'',
            'clargs':[],
            'crargs':[],
        },
        'interpreter':{
            'cmd':'gradle.bat',
            'clargs':['-b'],
            'crargs':[],
        },
    }
    implementation = 'jupyter_MyGradle_kernel'
    implementation_version = '1.0'
    language = 'Gradle'
    language_version = ''
    language_info = {'name': 'text/gradle',
                     'mimetype': 'text/gradle',
                     'file_extension': kernel_info['extension']}
    runfiletype='script'
    banner = "Gradle kernel.\n" \
             "Uses Gradle, compiles in gradle, and creates source code files and executables in temporary folder.\n"

    main_head = "\n\nint main(List<String> arguments){\n"
    main_foot = "\nreturn 0;\n}"
    
## //%include:../../src/comm_attribute.py
## __init__
    def __init__(self, *args, **kwargs):
        super(GradleKernel, self).__init__(*args, **kwargs)
        self.runfiletype='script'
        self.kernelinfo="[MyGradleKernel{0}]".format(time.strftime("%H%M%S", time.localtime()))
## #############################################
##%include:src/compile_out_file.py
##%include:src/compile_with_sc.py
##%include:src/c_exec_sc_.py

##%include:src/do_gradle_runcode.py
##%include:src/do_gradle_compilecode.py
##%include:src/do_gradle_create_codefile.py
##%include:src/do_gradle_preexecute.py
# Out:
# [MyPythonKernel144540] Info:file h:\Jupyter\Myjupyter-kernel\kernel\Gradle\..\..\..\jupyter-MyGradle-kernel\jupyter_MyGradle_kernel\kernel.py created successfully
