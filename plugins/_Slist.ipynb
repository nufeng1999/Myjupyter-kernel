# %%
##%overwritefile
## %file:src/filelist.py
##%fnlist:Python C Dart Kotlin Groovy Java
##%fnlist:Gjs Vala Nodejs Bash VBScript WLS Go Html TypeScript
##%fileforlist:../../jupyter-My$fnlist-kernel/plugins/filelist.py
##%noruncode
from typing import Dict, Tuple, Sequence,List
from plugins.ISpecialID import IStag,IDtag,IBtag,ITag
import re
import os
from shutil import copyfile,move
class MyFileList(IStag):
    kobj=None
    def getName(self) -> str:
        # self.kobj._write_to_stdout("setKernelobj setKernelobj setKernelobj\n")
        return 'MyFileList'
    def getAuthor(self) -> str:
        return 'Author'
    def getIntroduction(self) -> str:
        return 'MyFileList'
    def getPriority(self)->int:
        return 0
    def getExcludeID(self)->List[str]:
        return []
    def getIDSptag(self) -> List[str]:
        return ['filelist','fnlist']
    def setKernelobj(self,obj):
        self.kobj=obj
        # self.kobj._write_to_stdout("setKernelobj setKernelobj setKernelobj\n")
        return
    def on_shutdown(self, restart):
        return
    def on_ISpCodescanning(self,key, value,magics,line) -> str:
        # return self.filehander(self,key, value,magics,line)
        try:
            self.kobj.addkey2dict(magics,'filelist')
            if len(value)>0:
                for argument in re.findall(r'(?:[^\s,"]|"(?:\\.|[^"])*")+', value):
                    magics['filelist'] += [argument.strip('"')]
        except Exception as e:
            self.kobj._log(str(e),2)
        return ''
    ##在代码预处理前扫描代码时调用    
    def on_Codescanning(self,magics,code)->Tuple[bool,str]:
        pass
        return False,code
    ##生成文件时调用
    def on_before_buildfile(self,code,magics)->Tuple[bool,str]:
        return False,''
    def on_after_buildfile(self,returncode,srcfile,magics)->bool:
        return False
    def on_before_compile(self,code,magics)->Tuple[bool,str]:
        return False,''
    def on_after_compile(self,returncode,binfile,magics)->bool:
        return False
    def on_before_exec(self,code,magics)->Tuple[bool,str]:
        return False,''
    def on_after_exec(self,returncode,srcfile,magics)->bool:
        return False
    def on_after_completion(self,returncode,execfile,magics)->bool:
        magics['filelist']=[]
        return False
# Out:
# [MyPython] Info:../../jupyter-MyPython-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyC-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyDart-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyKotlin-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyGroovy-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyJava-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyGjs-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyVala-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyNodejs-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyBash-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyVBScript-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyWLS-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyGo-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyHtml-kernel/plugins/filelist.py
# [MyPython] Info:../../jupyter-MyTypeScript-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyC-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyDart-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyKotlin-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyGroovy-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyJava-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyGjs-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyVala-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyNodejs-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyBash-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyVBScript-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyWLS-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyGo-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyHtml-kernel/plugins/filelist.py
# [MyPython] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyTypeScript-kernel/plugins/filelist.py
# [MyPython] Info:file h:\Jupyter\Myjupyter-kernel\plugins\../../jupyter-MyPython-kernel/plugins/filelist.py created successfully
