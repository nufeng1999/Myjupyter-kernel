# %%
##%overwritefile
## %file:src/filelist.py
##%fnlist:CMake Mermaid
##%fnlist:Python C Dart Kotlin Groovy Java Batch PS R Swift Lua Perl PHP Tcl Vimscript M4 Dot
##%fnlist:Gjs Vala Nodejs Bash VBScript WLS Go Html TypeScript Make Ruby Rust
##%fileforlist:../../jupyter-My$fnlist-kernel/jupyter_My$fnlist_kernel/plugins/filelist.py
##%noruncode
from typing import Dict, Tuple, Sequence,List
from plugins.ISpecialID import IStag,IDtag,IBtag,ITag
import re
import os
from shutil import copyfile,move
class MyFileList(IStag):
    kobj=None
    def getName(self) -> str:
        # self.kobj._write_to_stdout("setKernelobj setKernelobj setKernelobj\n")
        return 'MyFileList'
    def getAuthor(self) -> str:
        return 'Author'
    def getIntroduction(self) -> str:
        return 'MyFileList'
    def getPriority(self)->int:
        return 0
    def getExcludeID(self)->List[str]:
        return []
    def getIDSptag(self) -> List[str]:
        return ['filelist','fnlist']
    def setKernelobj(self,obj):
        self.kobj=obj
        # self.kobj._write_to_stdout("setKernelobj setKernelobj setKernelobj\n")
        return
    def on_shutdown(self, restart):
        return
    def on_ISpCodescanning(self,key, value,magics,line) -> str:
        # return self.filehander(self,key, value,magics,line)
        try:
            self.kobj.addkey2dict(magics,'filelist')
            if len(value)>0:
                for argument in re.findall(r'(?:[^\s,"]|"(?:\\.|[^"])*")+', value):
                    magics['filelist'] += [argument.strip('"')]
        except Exception as e:
            self.kobj._log(str(e),2)
        return ''
    ##在代码预处理前扫描代码时调用    
    def on_Codescanning(self,magics,code)->Tuple[bool,str]:
        pass
        return False,code
    ##生成文件时调用
    def on_before_buildfile(self,code,magics)->Tuple[bool,str]:
        return False,''
    def on_after_buildfile(self,returncode,srcfile,magics)->bool:
        return False
    def on_before_compile(self,code,magics)->Tuple[bool,str]:
        return False,''
    def on_after_compile(self,returncode,binfile,magics)->bool:
        return False
    def on_before_exec(self,code,magics)->Tuple[bool,str]:
        return False,''
    def on_after_exec(self,returncode,srcfile,magics)->bool:
        return False
    def on_after_completion(self,returncode,execfile,magics)->bool:
        magics['filelist']=[]
        return False
# Out:
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyMermaid-kernel\jupyter_MyMermaid_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyPython-kernel\jupyter_MyPython_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyC-kernel\jupyter_MyC_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyDart-kernel\jupyter_MyDart_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyKotlin-kernel\jupyter_MyKotlin_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyGroovy-kernel\jupyter_MyGroovy_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyJava-kernel\jupyter_MyJava_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyBatch-kernel\jupyter_MyBatch_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyPS-kernel\jupyter_MyPS_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyR-kernel\jupyter_MyR_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MySwift-kernel\jupyter_MySwift_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyLua-kernel\jupyter_MyLua_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyPerl-kernel\jupyter_MyPerl_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyPHP-kernel\jupyter_MyPHP_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyTcl-kernel\jupyter_MyTcl_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyVimscript-kernel\jupyter_MyVimscript_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyM4-kernel\jupyter_MyM4_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyDot-kernel\jupyter_MyDot_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyGjs-kernel\jupyter_MyGjs_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyVala-kernel\jupyter_MyVala_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyNodejs-kernel\jupyter_MyNodejs_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyBash-kernel\jupyter_MyBash_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyVBScript-kernel\jupyter_MyVBScript_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyWLS-kernel\jupyter_MyWLS_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyGo-kernel\jupyter_MyGo_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyHtml-kernel\jupyter_MyHtml_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyTypeScript-kernel\jupyter_MyTypeScript_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyMake-kernel\jupyter_MyMake_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyRuby-kernel\jupyter_MyRuby_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:copy to :h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyRust-kernel\jupyter_MyRust_kernel\plugins\filelist.py
# [MyPythonKernel104329] Info:file h:\Jupyter\Myjupyter-kernel\plugins\..\..\jupyter-MyCMake-kernel\jupyter_MyCMake_kernel\plugins\filelist.py created successfully
